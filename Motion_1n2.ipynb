# %% [markdown]
# <a href="https://colab.research.google.com/github/rx2227/Motion-1-2/blob/main/Motion_1n2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools

# %%
# !wget -nc https://raw.githubusercontent.com/rx2227/Motion-1-2/main/Data%20h%3D5.4.csv
# !wget -nc https://raw.githubusercontent.com/rx2227/Motion-1-2/main/Data%20h%3D2.0.csv
# Out:
# --2023-10-18 06:41:30--  https://raw.githubusercontent.com/rx2227/Motion-1-2/main/Data%20h%3D5.4.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3512 (3.4K) [text/plain]
# Saving to: ‘Data h=5.4.csv’
#
# Data h=5.4.csv      100%[===================>]   3.43K  --.-KB/s    in 0s
#
# 2023-10-18 06:41:30 (31.9 MB/s) - ‘Data h=5.4.csv’ saved [3512/3512]
#
# --2023-10-18 06:41:30--  https://raw.githubusercontent.com/rx2227/Motion-1-2/main/Data%20h%3D2.0.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
ttwo, xtwo, vtwo, atwo, ptwo = np.loadtxt("Data h=2.0.csv", skiprows=3, unpack=True, delimiter=",")
tfiv, xfiv, vfiv, afiv, pfiv = np.loadtxt("Data h=5.4.csv", skiprows=3, unpack=True, delimiter=",")

# %%
figure, axis = plt.subplots(3, 1)

axis[0].plot(ttwo, xtwo)
#axis[0].ylabel("Distance(cm)")
axis[1].plot(ttwo, vtwo)
axis[2].plot(ttwo, atwo)
axis[0].set_xlabel('Time(s)')
axis[1].set_xlabel('Time(s)')
axis[2].set_xlabel('Time(s)')
axis[0].set_ylabel('Position(m)')
axis[1].set_ylabel('Velocity(m/s)')
axis[2].set_ylabel('Acceleration(m/s^2)')
# Out:
# Text(0, 0.5, 'Acceleration(m/s^2)')

# %%
figure, axis = plt.subplots(3, 1)

axis[0].plot(tfiv, xfiv)
#axis[0].ylabel("Distance(cm)")
axis[1].plot(tfiv, vfiv)
axis[2].plot(tfiv, afiv)
axis[0].set_xlabel('Time(s)')
axis[1].set_xlabel('Time(s)')
axis[2].set_xlabel('Time(s)')
axis[0].set_ylabel('Position(m)')
axis[1].set_ylabel('Velocity(m/s)')
axis[2].set_ylabel('Acceleration(m/s^2)')
# Out:
# Text(0, 0.5, 'Acceleration(m/s^2)')

# %%
def GetVelocity(x_1,x_2):
  Velocity = float((x_2 - x_1)/(1/25))
  return Velocity

x2_v = xtwo[2:]

VelocityArray = np.array([])
for (x_1,x_2) in zip(xtwo,x2_v):
  VelocityArray = np.append(VelocityArray, GetVelocity(x_1,x_2))

plt.scatter(ttwo[:-2],VelocityArray,s=5)
plt.scatter(ttwo,vtwo,s=5)
plt.legend(("Calculated from function","Calculated by Capstone"))
plt.xlabel("Time(s)")
plt.ylabel("Velocity(m/s)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
def GetAcceleration(x_1,x_2,x_3):
  Acceleration = (x_3 - 2*x_2 + x_1)/(1/50)**2
  return Acceleration

a_x_1 = xtwo
a_x_2 = xtwo[1:]
a_x_3 = xtwo[2:]

AccelerationArray = np.array([])
for (x_1,x_2,x_3) in zip(a_x_1,a_x_2,a_x_3):
  AccelerationArray = np.append(AccelerationArray,GetAcceleration(x_1,x_2,x_3))

plt.scatter(ttwo[:-2],AccelerationArray,s=5)
plt.scatter(ttwo,atwo,s=5)
plt.legend(("Calculated from function","Calculated by Capstone"))
plt.xlabel("Time(s)")
plt.ylabel("Acceleration(m/s^2)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
